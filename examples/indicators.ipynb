# %% [markdown]
# # Indicators

# %%
from src.tools import IndicatorsStore

store = IndicatorsStore('./data/indicators.xlsx')

# %%
store.tool.invoke({'query': 'Население'})
# Out:
# [Document(id='8112035', metadata={'Раздел': 'Население', 'Код показателя': 8112035, 'Единица измерения': 'Человек'}, page_content='Национальный состав населения'),
#  Document(id='8112013', metadata={'Раздел': 'Показатели для оценки эффективности деятельности органов местного самоуправления городских округов и муниципальных районов', 'Код показателя': 8112013, 'Единица измерения': 'Человек'}, page_content='Среднегодовая численность постоянного населения'),
#  Document(id='8112027', metadata={'Раздел': 'Население', 'Код показателя': 8112027, 'Единица измерения': 'Человек'}, page_content='Оценка численности населения на 1 января текущего года'),
#  Document(id='8312027', metadata={'Раздел': 'Показатели для оценки эффективности деятельности органов местного самоуправления городских округов и муниципальных районов', 'Код показателя': 8312027, 'Единица измерения': 'Человек'}, page_content='Оценка численности населения на 1 января текущего года'),
#  Document(id='8211002', metadata={'Раздел': 'Показатели для оценки эффективности деятельности органов местного самоуправления городских округов и муниципальных районов', 'Код показателя': 8211002, 'Единица измерения': 'Единица'}, page_content='Число жилых квартир в расчете на 1000 человек населения — всего'),
#  Document(id='8112016', metadata={'Раздел': 'Население', 'Код показателя': 8112016, 'Единица измерения': 'Человек'}, page_content='Численность сельского населения по полу и возрасту на 1 января текущего года'),
#  Document(id='8112014', metadata={'Раздел': 'Население', 'Код показателя': 8112014, 'Единица измерения': 'Человек'}, page_content='Численность всего населения по полу и возрасту на 1 января текущего года'),
#  Document(id='8155056', metadata={'Раздел': 'Показатели для оценки эффективности деятельности органов местного самоуправления городских округов и муниципальных районов', 'Код показателя': 8155056, 'Единица измерения': 'Процент'}, page_content='Доля населения, получившего жилые помещения и улучшившего жилищные условия , в общей численности населения, состоящего на учете в качестве нуждающегося в жилых помещениях'),
#  Document(id='8112015', metadata={'Раздел': 'Население', 'Код показателя': 8112015, 'Единица измерения': 'Человек'}, page_content='Численность городского населения по полу и возрасту на 1 января текущего года'),
#  Document(id='8008018', metadata={'Раздел': 'Коммунальная сфера', 'Код показателя': 8008018, 'Единица измерения': 'Единица'}, page_content='Количество негазифицированных населенных пунктов')]
