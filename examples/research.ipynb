# %% [markdown]
# # Research graph

# %%
SUBJECT = 'Ленинградская область'
DISTRICTS = {
    'boksitogorsk': 'Бокситогорский муниципальный район',
    'volosovo': 'Волосовский муниципальный район',
    'volhov': 'Волховский муниципальный район',
    'vsevolozhsk': 'Всеволожский муниципальный район',
    'vyborg': 'Выборгский муниципальный район',
    'kingisepp': 'Кингисеппский муниципальный район',
    'kirishi': 'Киришский муниципальный район',
    'kirovsk': 'Кировский муниципальный район',
    'lodeynoepole': 'Лодейнопольский муниципальный район',
    'lomonosov': 'Ломоносовский муниципальный район',
    'luga': 'Лужский муниципальный район',
    'podporozhye': 'Подпорожский муниципальный район',
    'priozersk': 'Приозерский муниципальный район',
    'slantsy': 'Сланцевский муниципальный район',
    'tihvin': 'Тихвинский муниципальный район',
    'tosno': 'Тосненский муниципальный район',
    'sosnovybor': 'Сосновоборский городской округ',
    'gatchina': 'Гатчинский муниципальный округ',
}
LOCATION = 'Гатчинский муниципальный округ (бывш. район) (Ленинградская область)'
YEAR = 2026
# PLAN = {
#     'социально-экономический анализ': [
#         'демография', 
#         'производительность труда', 
#         'структура и динамика ВГП', 
#         'рынок труда', 
#         'рынок жилья и коммерческой недвижимости', 
#         'бюджетная обеспеченность'
#     ],
#     'пространственный анализ': [
#         'функциональная организация территории', 
#         'структура землевладения', 
#         'природноэкологический каркас', 
#         'архитектурно-градостроительная среда'
#     ],
#     'транспортный анализ':[
#         'городской и внешний пассажирский и грузовой транспорт',
#         'парковки',
#         'пешеходные зоны',
#     ],
#     'анализ инженерной инфраструктуры':[
#         'водоснабжение и водоотведение', 
#         'энергоснабжение', 
#         'теплоснабжение',
#     ],
# }
PLAN = {
    'диагностика экономического и пространственного состояния МО': [
        'социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)',
        'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)',
        'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)',
        'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)',
    ]
}

# %%
PARAMS = {
    'location': LOCATION,
    'year': YEAR,
    'plan': PLAN
}

# %%
from src.graphs.qa.core import create_qa_graph

qa_graph = create_qa_graph()

# %%
from src.graphs.research.core import create_research_graph

research_graph = create_research_graph(qa_graph, 4, debug=True)

# %%
from src.tools import lightrag_tool

lightrag_tool.invoke('гатчина')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File /usr/lib/python3.10/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File /usr/lib/python3.10/http/client.py:323, in HTTPResponse.begin(self)
#     322 while True:
# --> 323     version, status, reason = self._read_status()
#     324     if status != CONTINUE:
#
# File /usr/lib/python3.10/http/client.py:284, in HTTPResponse._read_status(self)
#     283 def _read_status(self):
# --> 284     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     285     if len(line) > _MAXLINE:
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/nirma/.venv/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/util/retry.py:490, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     489 if read is False or method is None or not self._is_method_retryable(method):
# --> 490     raise reraise(type(error), error, _stacktrace)
#     491 elif read is not None:
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File ~/nirma/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPConnectionPool(host='localhost', port=9621): Read timed out. (read timeout=0.001)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from src.tools import lightrag_tool
# ----> 3 lightrag_tool.invoke('гатчина')
#
# File ~/nirma/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:642, in BaseTool.invoke(self, input, config, **kwargs)
#     634 @override
#     635 def invoke(
#     636     self,
#    (...)
#     639     **kwargs: Any,
#     640 ) -> Any:
#     641     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 642     return self.run(tool_input, **kwargs)
#
# File ~/nirma/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:1001, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     999 if error_to_raise:
#    1000     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1001     raise error_to_raise
#    1002 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1003 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File ~/nirma/.venv/lib/python3.10/site-packages/langchain_core/tools/base.py:967, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     965     if config_param := _get_runnable_config_param(self._run):
#     966         tool_kwargs |= {config_param: config}
# --> 967     response = context.run(self._run, *tool_args, **tool_kwargs)
#     968 if self.response_format == "content_and_artifact":
#     969     msg = (
#     970         "Since response_format='content_and_artifact' "
#     971         "a two-tuple of the message content and raw tool output is "
#     972         f"expected. Instead, generated response is of type: "
#     973         f"{type(response)}."
#     974     )
#
# File ~/nirma/.venv/lib/python3.10/site-packages/langchain_core/tools/structured.py:97, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      95     if config_param := _get_runnable_config_param(self.func):
#      96         kwargs[config_param] = config
# ---> 97     return self.func(*args, **kwargs)
#      98 msg = "StructuredTool does not support sync invocation."
#      99 raise NotImplementedError(msg)
#
# File ~/nirma/examples/src/tools/lightrag.py:9, in lightrag_tool(query)
#       4 @tool
#       5 def lightrag_tool(query : str):
#       6     """
#       7     Поиск по документам в LightRAG
#       8     """
# ----> 9     res = requests.post('http://localhost:9621/query', json={
#      10         'query': query,
#      11         'mode': 'mix',
#      12         'only_need_context': True,
#      13         'only_need_prompt': False,
#      14         'top_k': 5,
#      15         'chunk_top_k': 10,
#      16         'max_total_tokens': 1500,
#      17         'enable_rerank': False,
#      18         'include_references': True,
#      19         'include_chunk_content': True
#      20     }, timeout=0.001)
#      21     return res.text
#
# File ~/nirma/.venv/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/nirma/.venv/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/nirma/.venv/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/nirma/.venv/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/nirma/.venv/lib/python3.10/site-packages/requests/adapters.py:690, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     688     raise SSLError(e, request=request)
#     689 elif isinstance(e, ReadTimeoutError):
# --> 690     raise ReadTimeout(e, request=request)
#     691 elif isinstance(e, _InvalidHeader):
#     692     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPConnectionPool(host='localhost', port=9621): Read timed out. (read timeout=0.001)

# %%
res = research_graph.invoke({'params': PARAMS, 'max_iters': 1})
# Out:
# [values] {'params': {'location': 'Гатчинский муниципальный округ (бывш. район) (Ленинградская область)', 'year': 2026, 'plan': {'диагностика экономического и пространственного состояния МО': ['социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)']}}, 'results': {}, 'max_iters': 1}
# [updates] {'init': {'params': Params(location='Гатчинский муниципальный округ (бывш. район) (Ленинградская область)', year=2026, plan={'диагностика экономического и пространственного состояния МО': ['социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)']}), 'tasks': [('диагностика экономического и пространственного состояния МО', 'социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)'), ('диагностика экономического и пространственного состояния МО', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)'), ('диагностика экономического и пространственного состояния МО', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)'), ('диагностика экономического и пространственного состояния МО', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)')], 'results': {}, 'max_iters': 1}}
# [values] {'params': Params(location='Гатчинский муниципальный округ (бывш. район) (Ленинградская область)', year=2026, plan={'диагностика экономического и пространственного состояния МО': ['социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)']}), 'tasks': [('диагностика экономического и пространственного состояния МО', 'социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)'), ('диагностика экономического и пространственного состояния МО', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)'), ('диагностика экономического и пространственного состояния МО', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)'), ('диагностика экономического и пространственного состояния МО', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)')], 'results': {}, 'max_iters': 1}
# [updates] {'gate': {'tasks': [('диагностика экономического и пространственного состояния МО', 'социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)'), ('диагностика экономического и пространственного состояния МО', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)'), ('диагностика экономического и пространственного состояния МО', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)'), ('диагностика экономического и пространственного состояния МО', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)')]}}
# [values] {'params': Params(location='Гатчинский муниципальный округ (бывш. район) (Ленинградская область)', year=2026, plan={'диагностика экономического и пространственного состояния МО': ['социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)']}), 'tasks': [('диагностика экономического и пространственного состояния МО', 'социально-экономический анализ (демография, производительность труда, структура и динамика ВГП, рынок труда, рынок жилья и коммерческой недвижимости, бюджетная обеспеченность)'), ('диагностика экономического и пространственного состояния МО', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)'), ('диагностика экономического и пространственного состояния МО', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)'), ('диагностика экономического и пространственного состояния МО', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)')], 'results': {}, 'max_iters': 1}
# [updates] {'loop': None}
# [updates] {'worker_2': {'results': {('диагностика экономического и пространственного состояния МО', 'пространственный анализ (функциональная организация территории, структура землевладения, природноэкологический каркас, архитектурно-градостроительная среда)'): '## ПРОСТРАНСТВЕННЫЙ АНАЛИЗ ГАТЧИНСКОГО МУНИЦИПАЛЬНОГО ОКРУГА\n\n### 1. ФУНКЦИОНАЛЬНАЯ ОРГАНИЗАЦИЯ ТЕРРИТОРИИ\n\n**Административно-территориальное устройство:**\n- Гатчинский район существует с сентября 1927 года, муниципальный округ как форма муниципального образования образован в рамках муниципальной реформы\n- Административный центр - город Гатчина с населением до 150 тыс. человек\n- После образования муниципального округа поселения упразднены, остались только населенные пункты\n- Общая численность населения округа на 01.10.2023 года составляла 261 664 человека, требуется актуализация данных на 2024-2025 годы\n- Сельское население - 89 832 человека, расположено в 234 сельских населённых пунктах\n\n**Ключевые населённые пункты:**\n- Крупнейшие населённые пункты: Новый Свет, Большие Колпаны, Малое Верево, Пудость\n- Бывшие городские поселения: Дружногорское, Вырицкое\n- Бывшие сельские поселения: Пудостьское, Сяськелевское, Каложицкое, Зимитицкое, Бегуницкое, Клопицкое, Сельцовское, Губаницкое, Большеколпанское\n\n**Функциональное зонирование:**\n- Гатчина входит в зону агломерации, включающую 57 поселений\n- Округ является частью Санкт-Петербургской агломерации\n- Расстояние от административного центра до Санкт-Петербурга - 42 км\n- Гатчина включена в проект "Умный город"\n\n**Экономическая специализация:** отсутствует в исходных данных, требует дополнительного исследования промышленных зон, сельскохозяйственных территорий, рекреационных зон\n\n### 2. СТРУКТУРА ЗЕМЛЕВЛАДЕНИЯ\n\n**Общие характеристики:**\n- Общая площадь округа составляет 2,94 тыс. км²\n- Плотность населения в Гатчине - 3189,04 чел./км² (2020 год)\n\n**Землепользование:** отсутствуют конкретные данные о распределении земель по категориям (земли населенных пунктов, сельхозназначения, лесного фонда и др.), нет информации о формах собственности на землю\n\n**Зоны с особыми условиями:**\n- Установлены зоны с особыми условиями использования территорий для объектов энергетики\n- Действуют правила землепользования и застройки, утвержденные комиссией по подготовке проектов\n- Существуют специальные участки земли с охранными зонами магистральных трубопроводов\n\n**Планировочная структура:**\n- В апреле 2025 года начата разработка единого документа территориального планирования и градостроительного зонирования\n- Документ объединит генеральный план и правила землепользования и застройки\n- Планируется создание общественно-деловых и торгово-развлекательных кластеров\n\n**Текущее градостроительное зонирование:** отсутствует анализ текущего зонирования территории\n\n### 3. ПРИРОДНО-ЭКОЛОГИЧЕСКИЙ КАРКАС\n\n**Природные особенности:**\n- Значительная часть территории, особенно в юго-восточной части, заболочена\n- Крупнейшие озёра: Вялье и Орлинское\n- Территория характеризуется развитой водной сетью\n\n**Особо охраняемые природные территории:** отсутствуют конкретные данные по ООПТ на территории Гатчинского округа, требуется уточнение перечня и статуса охраняемых территорий\n\n**Экологические инициативы:**\n- Развитие экологического туризма на базе национальных парков\n- Создание тематических парков на базе объектов культурного наследия\n- Реализация природоохранных мероприятий в трансграничных водных объектах\n\n### 4. АРХИТЕКТУРНО-ГРАДОСТРОИТЕЛЬНАЯ СРЕДА\n\n**Культурно-историческое наследие:**\n- Гатчина является историческим поселением с особыми требованиями к использованию земельных участков и параметрам строительства\n- Город обладает уникальным дворцово-парковым ансамблем\n- Исторические поселения требуют соблюдения особых норм и ограничений для сохранения архитектурной ценности\n\n**Градостроительное развитие:**\n- Гатчина включена в национальный проект "Жилье и городская среда"\n- Стратегическая цель - повышени ...
# [updates] {'worker_3': {'results': {('диагностика экономического и пространственного состояния МО', 'транспортный анализ (городской и внешний пассажирский и грузовой транспорт, парковки, пешеходные зоны)'): '\n## Транспортный анализ Гатчинского муниципального округа (по состоянию на 2026 год)\n\n### Городской и пригородный пассажирский транспорт\n\n**Муниципальная транспортная реформа.** Гатчинский муниципальный округ стал пилотной территорией транспортной реформы в Ленинградской области. Обновление подвижного состава и маршрутной сети началось в конце 2024 – начале 2025 года и фактически опередило официальный старт реформы в регионе. По состоянию на середину 2025 года в округе работали 51 муниципальный маршрут общей протяженностью около 901 км, обслуживаемые парком порядка 100 автобусов. При этом точный статус реформы к 2026 году и степень выполнения плановых показателей требуют уточнения по официальным отчетам администрации.\n\n**Связь с Санкт‑Петербургом.** Гатчина связана с Санкт‑Петербургом железнодорожным и автобусным сообщением. В городе действуют станции Гатчина‑Варшавская и Гатчина‑Балтийская на направлениях Октябрьской железной дороги, обеспечивающие пригородные перевозки в сторону Санкт‑Петербурга и других населённых пунктов Ленинградской области. Интенсивность пассажиропотока, уровень заполняемости электричек и автобусов в часы пик, а также степень синхронизации расписаний с внутригородскими маршрутами остаются нераскрытыми и требуют отдельного исследования на основе данных перевозчиков и Росстата.\n\n### Железнодорожный транспорт и внешние транспортные коридоры\n\n**Железнодорожные магистрали.** Через территорию округа проходят линии Октябрьской железной дороги:\n- Варшавское направление;\n- Балтийское направление;\n- линия Мга – Ивангород.\n\nГатчина как железнодорожный узел потенциально важна для транзитных и местных пассажирских и грузовых потоков, однако количественные показатели (объёмы перевозок, структура грузов, загрузка станций и подъездных путей) в доступных источниках не детализированы.\n\n**Федеральные автомобильные дороги.** Округ находится в зоне влияния двух ключевых федеральных трасс:\n- автодорога А‑181 «Скандинавия»;\n- скоростная автодорога М‑11 «Нева».\n\nРеконструкция трассы «Скандинавия» с расширением проезжей части до шести полос и трёхкратным ростом пропускной способности при стоимости работ около 11,2 млрд руб. объективно повышает потенциал округа как логистического и транзитного узла. Вместе с тем конкретное расстояние от центра Гатчины до указанных трасс, состояние и качество подъездных путей, наличие и пропускная способность съездов/развязок, а также реальное использование этих трасс для грузовых и пассажирских перевозок по территории округа требуют уточнения по картографическим и проектным материалам.\n\n### Грузовые перевозки и логистика\n\nНа территории Гатчинского муниципального округа представлены коммерческие операторы грузовых перевозок, включая:\n- компании комплексных грузоперевозок («Грузовичкоф», ПЭК и др.);\n- авиационные и железнодорожные грузоперевозчики;\n- логистические и экспедиторские компании.\n\nНаличие таких операторов свидетельствует о спросе на грузовые перевозки и о включённости округа в межрегиональные и внутрироссийские логистические сети. При этом отсутствуют данные о:\n- объёмах грузоперевозок по территории округа;\n- наличии и мощности логистических центров, терминалов, складских комплексов;\n- структуре грузов (промышленные, сельскохозяйственные, потребительские, строительные);\n- влиянии транспортных издержек и доступности федеральных трасс на размещение и развитие бизнеса.\n\nЭти параметры необходимы для оценки роли транспортной инфраструктуры в экономике округа.\n\n### Парковочное пространство и организация движения\n\n**Парковочная инфраструктура.** В имеющихся источниках констатируется наличие стихийных парковок в городе Гатчина, что косвенно указывает на дефицит организованных парковочных мест и недостаточную упорядоченность парковочного режима. Однак ...
# [updates] {'worker_4': {'results': {('диагностика экономического и пространственного состояния МО', 'анализ инженерной инфраструктуры (водоснабжение и водоотведение, энергоснабжение, теплоснабжение)'): '**Инженерная инфраструктура Гатчинского муниципального округа: состояние и ограничения анализа на 2026 год**\n\n---\n\n### 1. Теплоснабжение\n\n- Утверждена актуализированная схема теплоснабжения Гатчинского муниципального округа на период до 2035 года постановлением от 21 июля 2025 года №154.  \n- Проведены публичные слушания по схеме теплоснабжения 25 августа 2025 года.  \n- Присвоен статус теплоснабжения Гатчинского муниципального округа на 2025 год.\n\nДоступные данные подтверждают наличие стратегического документа планирования теплоснабжения до 2035 года, но не содержат конкретных показателей по:\n- установленной тепловой мощности и ее загрузке;\n- протяженности и материалу тепловых сетей;\n- проценту износа основных фондов;\n- удельному весу аварийных и ветхих участков;\n- структуре источников теплоснабжения и резервированию.\n\n---\n\n### 2. Водоснабжение и водоотведение\n\n- Функционирует МУП «Водоканал» г. Гатчина (официальный сайт: vodokanal.gtn.ru).  \n- Разработаны и утверждены схемы водоснабжения и водоотведения для г. Гатчина и Гатчинского муниципального района.  \n- Централизованная система горячего водоснабжения использует закрытые схемы подключения к тепловым сетям.  \n- Утверждены тарифы на услуги водоснабжения и водоотведения на 2026 год.\n\nПри этом отсутствуют или не раскрыты в доступных источниках:\n- протяженность сетей водоснабжения и водоотведения по округу и по поселениям;\n- процент износа сетей и сооружений;\n- объемы подачи воды и отведения стоков в разрезе населенных пунктов;\n- данные по качеству питьевой воды и соответствию санитарным нормативам;\n- показатели аварийности и потерь в сетях;\n- планы модернизации и реконструкции водопроводно-канализационного хозяйства с объемами финансирования.\n\n---\n\n### 3. Энергоснабжение (электроэнергия)\n\n- Функционирует филиал ПАО «Ленэнерго» – Гатчинские электрические сети.  \n- Общая протяженность электрических сетей на территории обслуживания Гатчинских электрических сетей составляет:\n  - кабельные линии – 421,5 км;\n  - воздушные линии – 281,4 км.  \n- В апреле 2026 года завершен капитальный ремонт линий электропередачи в рамках плановой модернизации.\n\nИнформация о реконструкции ВЛ 330 кВ Гатчинская – Кингисеппская и о конкретной роли Ленинградской АЭС в электроснабжении Гатчинского муниципального округа в открытых источниках не детализирована. Отсутствуют:\n- баланс мощности и резервирование по питающим центрам;\n- данные по надежности электроснабжения (SAIDI, SAIFI и аналоги);\n- планы развития сетей в увязке с новым строительством и газификацией.\n\n---\n\n### 4. Административно-территориальный и статусный контекст\n\n- Гатчинский район преобразован в Гатчинский муниципальный округ 13 мая 2024 года.  \n- Гатчина с 3 апреля 2023 года имеет статус столицы Ленинградской области.\n\nЭти изменения усиливают требования к качеству и надежности инженерной инфраструктуры, но в имеющихся материалах не показано, как именно новые статусы и преобразования учтены в инвестиционных программах и схемах развития инженерных систем.\n\n---\n\n### 5. Критические пробелы для анализа экономического и пространственного состояния\n\n**5.1. Технико-эксплуатационные характеристики**\n\nНе представлены или недостаточно раскрыты:\n- степень износа основных фондов по теплоснабжению, водоснабжению и водоотведению, электроснабжению;\n- картографические данные о покрытии населенных пунктов округа инженерными сетями;\n- выделение дефицитных и избыточных по мощности узлов;\n- данные по аварийности и перерывам в предоставлении услуг.\n\n**5.2. Экономические и тарифные показатели**\n\nОтсутствует детализация:\n- инвестиционных программ предприятий ЖКХ и сетевых компаний с объемами и источниками финансирования;\n- обоснования тарифной политики и ее влияния на финансовую устойчивость  ...

# %%
import json

data = res['result']

with open("gatchina.json", "w") as outfile:
    json.dump(data, outfile)
